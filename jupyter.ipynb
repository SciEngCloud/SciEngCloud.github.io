# %% [markdown]
# # This is a demo of Jupyter and its graphics capabilities.
# This cell is a markdown cell. [shift-enter on the cell to render, double click to edit]

# %%
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
# %matplotlib inline

# %% [markdown]
# * Define a function to plot:
#   $f(x,y) =  1 - cos(x)cos(y)$
# * Define sample spacing for x and y and sample the function along the grid

# %%
def f(x, y):
    return 1 -  np.cos(y)*np.cos(x)

n_samples = 100
y_vec = np.linspace(0, 2*np.pi, n_samples)
x_vec = np.linspace(0, 2*np.pi, n_samples)
X,Y = np.meshgrid(x_vec, y_vec)
Z = f(X, Y).T

# %% [markdown]
# # Plot the function

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                    cmap=plt.get_cmap("coolwarm"), linewidth=0, 
                    antialiased=False)
cb = fig.colorbar(p, shrink=0.5)
